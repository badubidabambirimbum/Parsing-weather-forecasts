# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import time
import os
from table import table

# %%
'''
Moscow
Krasnodar
Ekaterinburg
'''
table = table()

# %%
table.view("Ekaterinburg","Yandex")
# Out:
#             day1  day2  day3  day4  day5  day6  day7  day8  day9  day10  ...  \
# date                                                                     ...
# 2024-07-01    28    23    29    32    30    28    28    28    27     28  ...
# 2024-07-02    24    29    32    32    30    26    25    27    27     27  ...
# 2024-07-03    29    32    32    29    28    25    24    27    26     22  ...
# 2024-07-04    32    32    28    29    26    27    29    24    20     22  ...
# 2024-07-05    32    28    28    24    28    29    29    22    20     24  ...
#
#                           weather1                weather2  \
# date
# 2024-07-01         Небольшой дождь         Небольшой дождь
# 2024-07-02         Небольшой дождь  Облачно с прояснениями
# 2024-07-03  Облачно с прояснениями         Небольшой дождь
# 2024-07-04             Малооблачно         Небольшой дождь
# 2024-07-05         Небольшой дождь  Облачно с прояснениями
#
#                           weather3                weather4  \
# date
# 2024-07-01  Облачно с прояснениями  Облачно с прояснениями
# 2024-07-02         Небольшой дождь  Облачно с прояснениями
# 2024-07-03         Небольшой дождь  Облачно с прояснениями
# 2024-07-04  Облачно с прояснениями  Облачно с прояснениями
# 2024-07-05  Облачно с прояснениями         Небольшой дождь
#
#                           weather5                weather6  \
# date
# 2024-07-01         Небольшой дождь  Облачно с прояснениями
# 2024-07-02  Облачно с прояснениями         Небольшой дождь
# 2024-07-03         Небольшой дождь         Небольшой дождь
# 2024-07-04  Облачно с прояснениями  Облачно с прояснениями
# 2024-07-05  Облачно с прояснениями  Облачно с прояснениями
#
#                           weather7         weather8         weather9  \
# date
# 2024-07-01         Небольшой дождь  Небольшой дождь  Небольшой дождь
# 2024-07-02         Небольшой дождь  Небольшой дождь  Небольшой дождь
# 2024-07-03         Небольшой дождь  Небольшой дождь  Небольшой дождь
# 2024-07-04  Облачно с прояснениями  Небольшой дождь  Небольшой дождь
# 2024-07-05         Небольшой дождь  Небольшой дождь  Небольшой дождь
#
#                   weather10
# date
# 2024-07-01  Небольшой дождь
# 2024-07-02  Небольшой дождь
# 2024-07-03  Небольшой дождь
# 2024-07-04  Небольшой дождь
# 2024-07-05  Небольшой дождь
#
# [5 rows x 30 columns]

# %%
print("Enter 'go' to start...")
input_1 = input()
if input_1 == "go":
    table.update("Moscow","GisMeteo")
    table.update("Krasnodar","GisMeteo")
    table.update("Ekaterinburg","GisMeteo")
else:
    raise Exception
# Out:
# Enter 'go' to start...
# GOOD!
# GOOD!
# GOOD!

# %%
print("Enter 'go' to start...")
input_2 = input()
if input_2 == "go":
    table.update("Moscow","Yandex")
    table.update("Krasnodar","Yandex")
else:
    raise Exception
# Out:
# Enter 'go' to start...
# GOOD!
# GOOD!

# %%
print("Enter 'go' to start...")
input_3 = input()
if input_3 == "go":
    table.update("Ekaterinburg","Yandex")
else:
    raise Exception
# Out:
# Enter 'go' to start...
# GOOD!
