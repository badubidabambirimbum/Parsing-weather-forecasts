# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import time
import os
from table import table

# %%
'''
Moscow
Krasnodar
Ekaterinburg
'''
table = table()

# %%
table.backup()
# Out:
# GOOD backup!

# %%
table.view("Ekaterinburg","Yandex")
# Out:
#             day1  day2  day3  day4  day5  day6  day7  day8  day9  day10  ...  \
# date                                                                     ...
# 2024-07-27    14    16    16    22    23    23    22    22    22     22  ...
# 2024-07-28    16    16    22    23    22    22    21    22    23     22  ...
# 2024-07-29    17    22    22    22    21    21    21    22    22     24  ...
# 2024-07-30    22    22    23    21    22    21    22    23    22     23  ...
# 2024-07-31    22    24    21    22    22    23    23    23    21     23  ...
#
#                    weather1         weather2         weather3  \
# date
# 2024-07-27            Дождь  Небольшой дождь  Небольшой дождь
# 2024-07-28  Небольшой дождь  Небольшой дождь         Пасмурно
# 2024-07-29            Дождь         Пасмурно  Небольшой дождь
# 2024-07-30         Пасмурно            Дождь         Пасмурно
# 2024-07-31   Дождь с грозой         Пасмурно         Пасмурно
#
#                           weather4                weather5  \
# date
# 2024-07-27                Пасмурно                Пасмурно
# 2024-07-28                Пасмурно          Дождь с грозой
# 2024-07-29                Пасмурно  Облачно с прояснениями
# 2024-07-30         Небольшой дождь         Небольшой дождь
# 2024-07-31  Облачно с прояснениями  Облачно с прояснениями
#
#                           weather6                weather7  \
# date
# 2024-07-27          Дождь с грозой  Облачно с прояснениями
# 2024-07-28  Облачно с прояснениями         Небольшой дождь
# 2024-07-29          Дождь с грозой         Небольшой дождь
# 2024-07-30          Дождь с грозой  Облачно с прояснениями
# 2024-07-31  Облачно с прояснениями         Небольшой дождь
#
#                           weather8         weather9               weather10
# date
# 2024-07-27         Небольшой дождь  Небольшой дождь         Небольшой дождь
# 2024-07-28         Небольшой дождь  Небольшой дождь         Небольшой дождь
# 2024-07-29         Небольшой дождь  Небольшой дождь  Облачно с прояснениями
# 2024-07-30  Облачно с прояснениями  Небольшой дождь  Облачно с прояснениями
# 2024-07-31         Небольшой дождь  Небольшой дождь         Небольшой дождь
#
# [5 rows x 30 columns]

# %%
print("Enter 'go' to start...")
input_1 = input()
if input_1 == "go":
    table.update("Moscow","GisMeteo")
    table.update("Krasnodar","GisMeteo")
    table.update("Ekaterinburg","GisMeteo")
else:
    raise Exception
# Out:
# Enter 'go' to start...
# GOOD!
# GOOD!
# GOOD!

# %%
print("Enter 'go' to start...")
input_2 = input()
if input_2 == "go":
    table.update("Moscow","Yandex")
    table.update("Krasnodar","Yandex")
else:
    raise Exception
# Out:
# Enter 'go' to start...
# GOOD!
# GOOD!

# %%
print("Enter 'go' to start...")
input_3 = input()
if input_3 == "go":
    table.update("Ekaterinburg","Yandex")
else:
    raise Exception
# Out:
# Enter 'go' to start...
# GOOD!
